# %%
from neutrondiffusion import neutrondiffusion

fig = neutrondiffusion(mat_flag = 'reflector', BC_flag = 'vacuum', bigsquare=.1, smallsquare=.01)
fig[0].savefig('bottom_v10_ref.png')
fig[1].savefig('diag_v10_ref.png')
# Out:
# optimize > constrained 160/1681 dofs
# optimize > optimum value 0.00e+00
# solve > solving 1521 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 1e-18

# %%
from neutrondiffusion import neutrondiffusion

# %%
fig = neutrondiffusion(mat_flag = 'reflector', BC_flag = 'reflecting', bigsquare=.1, smallsquare=.01)
fig[0].savefig('bottom_r10_ref3.png')
fig[1].savefig('diag_r10_ref3.png')
# Out:
# solve > solving 3721 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 3e-16

# %%
fig = neutrondiffusion(mat_flag = 'scatterer', BC_flag = 'vacuum', bigsquare=.1, smallsquare=.01)
fig[0].savefig('bottom_v10_scat.png')
fig[1].savefig('diag_v10_scat.png')
# Out:
# optimize > constrained 160/1681 dofs
# optimize > optimum value 0.00e+00
# solve > solving 1521 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 2e-18

# %%
fig = neutrondiffusion(mat_flag = 'scatterer', BC_flag = 'reflecting', bigsquare=.1, smallsquare=.01)
fig[0].savefig('bottom_r10_scat.png')
fig[1].savefig('diag_r10_scat.png')
# Out:
# solve > solving 441 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 2e-15

# %%
fig = neutrondiffusion(mat_flag = 'absorber', BC_flag = 'vacuum', bigsquare=.1, smallsquare=.01)
fig[0].savefig('bottom_v10_abs.png')
fig[1].savefig('diag_v10_abs.png')
# Out:
# optimize > constrained 160/1681 dofs
# optimize > optimum value 0.00e+00
# solve > solving 1521 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 5e-18

# %%
fig = neutrondiffusion(mat_flag = 'absorber', BC_flag = 'reflecting', bigsquare=.1, smallsquare=.01)
fig[0].savefig('bottom_r10_abs.png')
fig[1].savefig('diag_r10_abs.png')
# Out:
# solve > solving 1681 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 1e-17

# %%
fig = neutrondiffusion(mat_flag = 'air', BC_flag = 'vacuum', bigsquare=.1, smallsquare=.01)
fig[0].savefig('bottom_v10_air.png')
fig[1].savefig('diag_v10_air.png')
# Out:
# optimize > constrained 160/1681 dofs
# optimize > optimum value 0.00e+00
# solve > solving 1521 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 2e-19

# %%
fig = neutrondiffusion(mat_flag = 'air', BC_flag = 'reflecting', bigsquare=.1, smallsquare=.01)
fig[0].savefig('bottom_r10_air.png')
fig[1].savefig('diag_r10_air.png')
# Out:
# solve > solving 1681 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 2e-12

# %%
#increased number of meshes
fig = neutrondiffusion(mat_flag = 'scatterer', BC_flag = 'reflecting', bigsquare=.1, smallsquare=.01)
fig[0].savefig('bottom_v10_scat2.png')
fig[1].savefig('diag_v10_scat2.png')
# Out:
# solve > solving 1681 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 4e-15

# %%
#decreased number of meshes
fig = neutrondiffusion(mat_flag = 'scatterer', BC_flag = 'reflecting', bigsquare=.1, smallsquare=.01)
fig[0].savefig('bottom_v10_scat_half.png')
fig[1].savefig('diag_v10_scat_half.png')
# Out:
# solve > solving 121 dof system to machine precision using arnoldi solver
# solve > solver returned with residual 5e-16
